# %%
print("hello fucker!")
# Out:
# hello fucker!

# %%
import pandas
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model.predict(source = '/home/pheonix/Pictures/deadpool.jpg')
print(results)
# Out:
# image 1/1 /home/pheonix/Pictures/deadpool.jpg: 352x640 2 persons, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")  # pretrained YOLO11n model

results = model("/home/pheonix/Downloads/png.png",save = True)  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    # masks = result.masks  # Masks object for segmentation masks outputs
    # keypoints = result.keypoints  # Keypoints object for pose outputs
    # probs = result.probs  # Probs object for classification outputs
    # obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# image 1/1 /home/pheonix/Downloads/png.png: 384x640 1 person, 2 remotes, 49.0ms
# Speed: 1.8ms preprocess, 49.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict5

# %%
from ultralytics import YOLO

# Load the YOLO model
model = YOLO('yolov8n.pt')

# Predict using a webcam (use 0 for the default webcam)
# model.predict(source=0, show=True)

try:
    
    results = model.predict(source='/home/pheonix/Downloads/H.mp4', save=True, project='custom_folder', name='video_results')
    # model.predict(source=0, show=True)

    
except KeyboardInterrupt:
    print("Execution stopped.")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/12701) /home/pheonix/Downloads/H.mp4: 384x640 9 kites, 1 vase, 172.4ms
# video 1/1 (frame 2/12701) /home/pheonix/Downloads/H.mp4: 384x640 9 kites, 1 vase, 59.7ms
# video 1/1 (frame 3/12701) /home/pheonix/Downloads/H.mp4: 384x640 9 kites, 1 vase, 54.5ms
# video 1/1 (frame 4/12701) /home/pheonix/Downloads/H.mp4: 384x640 9 kites, 1 vase, 57.6ms
# ...
